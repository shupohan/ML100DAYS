# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $  <br/>
# $ MAE = \frac{1}{n}\sum_{i=1}^{n}{\vert(Y_i - \hat{Y}_i)\vert} $

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

def mean_square_error(y, yp):
    mse = sum(np.square(y-yp)) / len(y)
    return mse

# %% [markdown]
# For random samples from $N(\mu, \sigma^2)$, use: <br/>
# sigma * np.random.randn(...) + mu <br/>

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_square_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean square error is 222.052
# The Mean absolute error is 11.491

# %% [markdown]
# # 作業2
#
# 1. 你選的這組資料為何重要<br/>
# [Data](https://www.kaggle.com/jackywang529/michelin-restaurants) It can give us an idea of the distribution of michelin restaurant. By this dataset, we can get a picture of the trend of the world-leading restaurant.
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br/>
# This data is collected from the restaurants which have win michilin star in 2019.
# 3. 蒐集而來的資料型態為何<br/>
# Data format is both numbers and words.
# 4. 這組資料想解決的問題如何評估<br/>
# To classify what kind of combination of price, cuisine and city can get michelin star.

# %% [markdown]
# # 作業3
#
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br/>
# The main question is how to use the collected data to promte performance. The passengers per hour should increase after analyzing our data. Therefore, we can earn more money with the same number of cars.
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br/>
# The data come from the GPS and the sensors on the car. We need to know whether the cars have drive on the optimal path; in the meantime, we also need to know the condition on the car as another factors. Therefore, the dataset must includes GPS path and sensors on the car.
# 3. 蒐集而來的資料型態為何<br/>
# The data format is number. The numbers is the latitude and longitude of the path and sensor data on the car.
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br/>
# Compare the income of the company before and after the adjustment. If the adjustment based on the data have better performance, we can assume our analysis works.
